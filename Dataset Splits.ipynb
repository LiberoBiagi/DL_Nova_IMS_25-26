# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.21.0

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# I am going to create a csv file that contains metadata about all of our pictures, with the structure _image_path, author_.

# %%
DATASET_DIR = "wikiart" 
OUTPUT_CSV = "metadata.csv"

data = []

for author in sorted(os.listdir(DATASET_DIR)):
    author_path = os.path.join(DATASET_DIR, author)

    # Skip anything that is not a folder
    if not os.path.isdir(author_path):
        continue
    
    for img_name in sorted(os.listdir(author_path)):
        if img_name.lower().endswith((".jpg", ".jpeg", ".png")):
            img_path = os.path.join(author_path, img_name)
            data.append({"image_path": img_path, "author": author})

df = pd.DataFrame(data)

df = df.sample(frac=1, random_state=42).reset_index(drop=True) # shuffles the data

df.to_csv(OUTPUT_CSV, index=False)

print(f"Saved {len(df)} entries to {OUTPUT_CSV}")
# Out:
# Saved 13340 entries to metadata.csv

# %% [markdown]
# Now I am going to split the data stratifying by author.

# %%
SEED = 42

df = pd.read_csv("dataset/metadata.csv")

train_val_df, test_df = train_test_split(
    df,
    test_size=0.2,
    stratify=df["author"],
    random_state=SEED
)

train_df, val_df = train_test_split(
    train_val_df,
    test_size=0.2,
    stratify=train_val_df["author"],
    random_state=SEED
)

print(len(train_df), len(val_df), len(test_df))
# Out:
# 8537 2135 2668

# %% [markdown]
# Now I'm going to save these splits.

# %%
train_df.to_csv("splits/train.csv", index=False)
val_df.to_csv("splits/val.csv", index=False)
test_df.to_csv("splits/test.csv", index=False)

# %% [markdown]
# Now everytime that we need to work we will all load the csv files from Github like this **(DON'T RESPLIT)**

# %%
train_df = pd.read_csv("splits/train.csv")
val_df = pd.read_csv("splits/val.csv")
test_df = pd.read_csv("splits/test.csv")

# %%
train_df
# Out:
#                                              image_path                 author
# 0     wikiart/Edgar_Degas/edgar-degas_portrait-of-pr...            Edgar_Degas
# 1     wikiart/Nicholas_Roerich/nicholas-roerich_ridg...       Nicholas_Roerich
# 2     wikiart/Ivan_Shishkin/ivan-shishkin_herd-of-sh...          Ivan_Shishkin
# 3     wikiart/Eugene_Boudin/eugene-boudin_gypsy-hors...          Eugene_Boudin
# 4     wikiart/Pierre_Auguste_Renoir/pierre-auguste-r...  Pierre_Auguste_Renoir
# ...                                                 ...                    ...
# 8532  wikiart/Raphael_Kirchner/raphael-kirchner_port...       Raphael_Kirchner
# 8533  wikiart/Nicholas_Roerich/nicholas-roerich_sanc...       Nicholas_Roerich
# 8534  wikiart/Eugene_Boudin/eugene-boudin_bathers-on...          Eugene_Boudin
# 8535  wikiart/Pierre_Auguste_Renoir/pierre-auguste-r...  Pierre_Auguste_Renoir
# 8536  wikiart/Ivan_Aivazovsky/ivan-aivazovsky_chumak...        Ivan_Aivazovsky
#
# [8537 rows x 2 columns]
